# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
# !pwd
# Out:
# /content/drive/MyDrive

# %%
#!git clone https://github.com/MCG-NJU/EMA-VFI.git
# Out:
# Cloning into 'EMA-VFI'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 97 (delta 35), reused 32 (delta 32), pack-reused 49
# Receiving objects: 100% (97/97), 8.14 MiB | 14.01 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
# %cd /content/drive/MyDrive/EMA-VFI
# Out:
# /content/drive/MyDrive/EMA-VFI

# %%
#!python benchmark/Vimeo90K.py --model ours --path /content/drive/MyDrive/dataset
# Out:
# =========================Starting testing=========================
# Dataset: Vimeo90K   Model: ours   TTA: True
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/EMA-VFI/benchmark/Vimeo90K.py", line 50, in <module>
#     f = open(path + '/tri_testlist.txt', 'r')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/dataset/tri_testlist.txt'

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 35.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !python demo_Nx.py --n 8
# Out:
# =========================Start Generating=========================
# Shape of image 0: (480, 854, 3)
# Shape of image 1: (480, 854, 3)
# Shape of image 2: (480, 854, 3)
# Shape of image 3: (480, 854, 3)
# Shape of image 4: (480, 854, 3)
# Shape of image 5: (480, 854, 3)
# Shape of image 6: (480, 854, 3)
# Shape of image 7: (480, 854, 3)
# Shape of image 8: (480, 854, 3)
# =========================Done=========================
